# %%
import json 
import pandas
import os.path
from math import log
from enum import Enum

# %% [markdown]
# ## weight star rating by review count

# %%
def __weightedStars(stars, count):
        
    try:
        count = int(count)
    except ValueError:
        return 'NA'
    
    if not(1 <= stars <= 5):
        return 'NA'
    else:
        normalStars = stars - 3 # 'neutral' rating of 3 normalized to 0
        return normalStars * log(count)

# %% [markdown]
# ## levels of alcohol service

# %%
class __Alcohol(Enum):
    none = 0
    beer_and_wine = 1
    full_bar = 2

# %% [markdown]
# ## return clean and organised data

# %%
def getData(fromCache=True):
    dataDirectory = '../data/yelp/'
    outputName = 'restaurants_clean.csv'
    
    if fromCache & os.path.isfile(dataDirectory + outputName):
        return pandas.read_csv(dataDirectory + outputName, header=0, index_col='business_id')
    
    else:
    
        # read-in .json file as pandas dataframe
        businesses = (pandas.DataFrame.from_dict([json.loads(data) for data in 
                      open(dataDirectory + 'yelp_academic_dataset_business.json', 'r')])
                     )

        # select study area data & filter restaurants
        selectedData = (businesses[(businesses.state == 'AZ') & 
                                   businesses.categories.apply(lambda categories: 
                                                                   'Restaurants' in categories)
                                  ]
                        .set_index('business_id')
                        .drop(['neighborhoods', 'open', 'city', 'state', 'type'], axis = 1)
                       )
                                   
        # recode nested variables
        selectedData["rating"] = selectedData.apply(
            lambda row: __weightedStars(row.stars, row.review_count),axis=1
        )

        selectedData["alcohol"] = selectedData.apply(
            lambda row: __Alcohol[row.attributes.get('Alcohol', 'none')].value, axis=1
        )

        selectedData["price_range"] = selectedData.apply(
            lambda row: row.attributes.get('Price Range', 'NA'), axis=1
        )

        selectedData["attire"] = selectedData.apply(
            lambda row: row.attributes.get('Attire', 'casual'), axis=1
        )

        selectedData["takeout"] = selectedData.apply(
            lambda row: row.attributes.get('Take-out', 'NA'), axis=1
        )

        selectedData["waiter_service"] = selectedData.apply(
            lambda row: row.attributes.get('Waiter Service', 'NA'), axis=1
        )

        selectedData["outdoor_seating"] = selectedData.apply(
            lambda row: 
                row.attributes.get('Outdoor Seating', 'NA'), axis=1
        )
        
        selectedData.drop(["attributes", "categories", "hours", "review_count", "stars"], 
                                 axis=1, inplace=True)
    
        selectedData.to_csv(dataDirectory + outputName)
        return selectedData

# %%
getData()
# Out:
#                                                              full_address  \
# business_id
# x5Mv61CnZLohZWxfCVCPTQ              2819 N Central Ave\nPhoenix, AZ 85004
# 2ZnCITVa0abGce4gZ6RhIw              1850 N Central Ave\nPhoenix, AZ 85004
# EmzaQR5hQlF0WIl24NxAZA             132 E Washington St\nPhoenix, AZ 85004
# KPoTixdjoJxSqRSEApSAGg              2631 N Central Ave\nPhoenix, AZ 85004
# e5kc0CQ4R-PCCDgb274gSg           455 N 3rd St\nSte 114\nPhoenix, AZ 85004
# gBcpDl0quCLABsg5OuSFww                  622 E Adams St\nPhoenix, AZ 85004
# 72N6TdH5MdUWE2YhYRbyxw              2530 N Central Ave\nPhoenix, AZ 85004
# eOgUKCy5-sK-leqIBiNokg                 2 N Central Ave\nPhoenix, AZ 85004
# neGAQFkBNI8-rpPBLBzNkw          301 East McDowell Road\nPhoenix, AZ 85004
# 45puCRQ6Vh_IIAy7kkfFDQ                     24 N 2nd St\nPhoenix, AZ 85004
# nc3IiY5LNdmEwUZCW84yuA                    455 N 3rd St\nPhoenix, AZ 85004
# P7wKlbSRsoRrfH3DFOY08A              2508 N Central Ave\nPhoenix, AZ 85004
# BESmH-lmMm34_EefL8X9fQ              1830 S Central Ave\nPhoenix, AZ 85004
# D09yG6Z3gcsh24Qn7Y4gYA      530 E McDowell Rd\nSte 103\nPhoenix, AZ 85004
# kaIue7GRCmkPzDeHDBTttQ              1401 N Central Ave\nPhoenix, AZ 85004
# j8nyAaN_w5t6wYv-ni23sg                    412 S 3rd St\nPhoenix, AZ 85004
# 5XIvwfbIa-vuFEkkeCQ6kQ                245 E Jackson St\nPhoenix, AZ 85004
# VsO_rhXi5lgbaGxNwoEZsQ                    905 N 4th St\nPhoenix, AZ 85004
# Y293fHh5SZ0_9BZm4M6BCg                  125 E Adams St\nPhoenix, AZ 85004
# IceZ4BtTz76eppjNWm-c6A               1030 NW Grand Ave\nPhoenix, AZ 85007
# QsvRjgQacMMFf8dit7qqDw               823 S Central Ave\nPhoenix, AZ 85004
# LXhL5X3edNRy7epku6UAEw             3 S 2nd St\nSte 205\nPhoenix, AZ 85004
# -lOSaCuBRAvX5JBifx-EMw                    455 N 3rd St\nPhoenix, AZ 85004
# XI-_Y2XRw03mozGx0Z90Gw                50 N Central Ave\nPhoenix, AZ 85004
# qsWxbgQwuomXvMseg23DGg   455 N 3rd\n190 Arizona Center\nPhoenix, AZ 85004
# DlCtdbceo4YNSI53cCL2lg              1418 N Central Ave\nPhoenix, AZ 85004
# kR5i58Pcse1FD9tk-yYLlA              541 E Van Buren St\nPhoenix, AZ 85004
# 2I666dqzs1XB6xigIKa9bA                 2 N Central Ave\nPhoenix, AZ 85004
# yExYqENb4F6qH6kJxTOaSQ     333 E Jefferson St\nSte 102\nPhoenix, AZ 85004
# 9BH18avE46LlHMvJn67MaA               130 N Central Ave\nPhoenix, AZ 85004
# ...                                                                   ...
# B4DU-hCTykF5_2q-9I4Chw       25101 N Lake Pleasant Pkwy\nPeoria, AZ 85383
# vT0hDJ9AL495p2tRYd922Q      21374 S Ellsworth Loop\nQueen Creek, AZ 85142
# C_uN2pHwP4DlRwzAKVsabQ             100 Easy St\nSte 2\nCarefree, AZ 85377
# AHcDWLn-OZR7qxoXwyfBoQ              2210 N Scottsdale Rd\nTempe, AZ 85281
# p9FwRY_KnxEHSI5op2qOvw       4539 E Thomas Rd\nSte 105\nPhoenix, AZ 85018
# oMGhGXF_qCpM-eZSyfjOgw               424 N Central Ave\nPhoenix, AZ 85004
# OaJyFHQA-pAHsD_ev0fIWg                 4 E University Dr\nTempe, AZ 85281
# py3nEoU90ZjVW7fPphNe8A                   1310 S. Longmore\nMesa, AZ 85202
# d6xkQMRMFe-ZQAzBNkHuLw               414 W University Dr\nTempe, AZ 85281
# CC8-73NAWvXKE1ArCkdMfg             9460 W. Hanna Lane\nGlendale, AZ 85305
# NmDm0CFwN1YrqqqLZ4CCsg               405 W University Dr\nTempe, AZ 85281
# TaKm7DeRsxz-xFVWX9XzPA  10144 Lake Pleasant Pkwy\nSte 1130\nPeoria, AZ...
# 97j8fecPqs_7-qbCjTlLEw  6751 North Sunset Boulevard\nSte E109\nGlendal...
# dMU3G63r4lo8iHIxGW5dXw  17221 N. Litchfield Rd\nSte 50\nSurprise, AZ 8...
# cx6ht6xrOwHpNhXVQtgxiQ             9425 W Coyote Blvd\nGlendale, AZ 85305
# d5UL7UjVnbJs8aiKzTCveg  Paradise Valley Mall\n4568 E Cactus Rd, Ste 11...
# qjRBMRCUlUx8Ofe9tiSlTA              4500 N 12th Street\nPhoenix, AZ 85014
# MOy6W061xpZq6co1nmEcfA             69 N Frontier St\nWickenburg, AZ 85390
# zI9jtvCdSwIRwtY8qGdMpg  9145-9161 East Indian Bend Road\nScottsdale, A...
# I7uXE-VzXK3Cp4mvVp7osw              1017 N Central Ave\nPhoenix, AZ 85004
# i0qvOlxRMYTYm0ZG4BEulg             1509 N Arizona Ave\nChandler, AZ 85225
# MjnSTmlGlTt4LkKTao20FA        8960 W Bell Rd\nSte 110-A\nPeoria, AZ 85382
# RbX5oXtNRuCqKiYchHRNFw  16635 N Tatum Blvd\nSte 100\nScottsdale, AZ 85254
# WCCRd8g_c6Hf93GAW4OjPQ               306 w. yavapai st\nPhoenix, AZ 85003
# FaymdoTfBSdPwg_ZfUE8zg         20401 S Sossaman Rd\nQueen Creek, AZ 85142
# dtlk15Awa7xWEVF9Z1Yqaw               20199 N 67th Ave\nGlendale, AZ 85308
# T-LhjPRqlS7hLGRmSMBbfA                6348 S Higley Rd\nGilbert, AZ 85298
# rtqtZ0_kOA-GP33mn6-Kpg        9875 W Lower Buckeye Rd\nTolleson, AZ 85353
# 7Hmr1TDJah-14zprHUMlqw            757 E Chandler Blvd\nChandler, AZ 85225
# CVakWZjk_j44AB-Jbe0DPQ    4040 S. Arizona Ave\nSte 17\nChandler, AZ 85248
#
#                          latitude   longitude  \
# business_id
# x5Mv61CnZLohZWxfCVCPTQ  33.479482 -112.073681
# 2ZnCITVa0abGce4gZ6RhIw  33.468547 -112.075085
# EmzaQR5hQlF0WIl24NxAZA  33.448399 -112.071702
# KPoTixdjoJxSqRSEApSAGg  33.477939 -112.073417
# e5kc0CQ4R-PCCDgb274gSg  33.452154 -112.068620
# gBcpDl0quCLABsg5OuSFww  33.449298 -112.065542
# 72N6TdH5MdUWE2YhYRbyxw  33.476260 -112.074248
# eOgUKCy5-sK-leqIBiNokg  33.448491 -112.074428
# neGAQFkBNI8-rpPBLBzNkw  33.465440 -112.069090
# 45puCRQ6Vh_IIAy7kkfFDQ  33.448465 -112.071257
# nc3IiY5LNdmEwUZCW84yuA  33.452154 -112.068620
# P7wKlbSRsoRrfH3DFOY08A  33.475583 -112.074115
# BESmH-lmMm34_EefL8X9fQ  33.429424 -112.073929
# D09yG6Z3gcsh24Qn7Y4gYA  33.465712 -112.065729
# kaIue7GRCmkPzDeHDBTttQ  33.464098 -112.073569
# j8nyAaN_w5t6wYv-ni23sg  33.443909 -112.070122
# 5XIvwfbIa-vuFEkkeCQ6kQ  33.445036 -112.070627
# VsO_rhXi5lgbaGxNwoEZsQ  33.457913 -112.068678
# Y293fHh5SZ0_9BZm4M6BCg  33.449309 -112.071940
# IceZ4BtTz76eppjNWm-c6A  33.454765 -112.086517
# QsvRjgQacMMFf8dit7qqDw  33.439268 -112.073481
# LXhL5X3edNRy7epku6UAEw  33.447073 -112.070977
# -lOSaCuBRAvX5JBifx-EMw  33.452154 -112.068620
# XI-_Y2XRw03mozGx0Z90Gw  33.448751 -112.073815
# qsWxbgQwuomXvMseg23DGg  33.452335 -112.069614
# DlCtdbceo4YNSI53cCL2lg  33.464250 -112.074153
# kR5i58Pcse1FD9tk-yYLlA  33.450875 -112.066333
# 2I666dqzs1XB6xigIKa9bA  33.448425 -112.074802
# yExYqENb4F6qH6kJxTOaSQ  33.445802 -112.069107
# 9BH18avE46LlHMvJn67MaA  33.449952 -112.074051
# ...                           ...         ...
# B4DU-hCTykF5_2q-9I4Chw  33.713806 -112.260103
# vT0hDJ9AL495p2tRYd922Q  33.256893 -111.638555
# C_uN2pHwP4DlRwzAKVsabQ  33.824113 -111.922769
# AHcDWLn-OZR7qxoXwyfBoQ  33.452530 -111.926887
# p9FwRY_KnxEHSI5op2qOvw  33.479871 -111.983118
# oMGhGXF_qCpM-eZSyfjOgw  33.453233 -112.074239
# OaJyFHQA-pAHsD_ev0fIWg  33.422192 -111.939615
# py3nEoU90ZjVW7fPphNe8A  33.390602 -111.864378
# d6xkQMRMFe-ZQAzBNkHuLw  33.422175 -111.945365
# CC8-73NAWvXKE1ArCkdMfg  33.534942 -112.261923
# NmDm0CFwN1YrqqqLZ4CCsg  33.421479 -111.945394
# TaKm7DeRsxz-xFVWX9XzPA  33.677972 -112.277618
# 97j8fecPqs_7-qbCjTlLEw  33.533779 -112.261797
# dMU3G63r4lo8iHIxGW5dXw  33.641025 -112.358386
# cx6ht6xrOwHpNhXVQtgxiQ  33.533049 -112.262036
# d5UL7UjVnbJs8aiKzTCveg  33.602694 -111.983231
# qjRBMRCUlUx8Ofe9tiSlTA  33.502143 -112.056506
# MOy6W061xpZq6co1nmEcfA  33.968708 -112.731422
# zI9jtvCdSwIRwtY8qGdMpg  33.537981 -111.884119
# I7uXE-VzXK3Cp4mvVp7osw  33.459414 -112.073529
# i0qvOlxRMYTYm0ZG4BEulg  33.330828 -111.841001
# MjnSTmlGlTt4LkKTao20FA  33.639553 -112.252310
# RbX5oXtNRuCqKiYchHRNFw  33.638216 -111.977453
# WCCRd8g_c6Hf93GAW4OjPQ  33.436169 -112.077588
# FaymdoTfBSdPwg_ZfUE8zg  33.262859 -111.668974
# dtlk15Awa7xWEVF9Z1Yqaw  33.667037 -112.202556
# T-LhjPRqlS7hLGRmSMBbfA  33.235110 -111.720624
# rtqtZ0_kOA-GP33mn6-Kpg  33.420859 -112.271287
# 7Hmr1TDJah-14zprHUMlqw  33.305778 -111.828761
# CVakWZjk_j44AB-Jbe0DPQ  33.246338 -111.842483
#
#                                                          name    rating  \
# business_id
# x5Mv61CnZLohZWxfCVCPTQ                         Domino's Pizza -1.386294
# 2ZnCITVa0abGce4gZ6RhIw                 Viad Tower Restaurants  0.895880
# EmzaQR5hQlF0WIl24NxAZA                             Sky Lounge -1.609438
# KPoTixdjoJxSqRSEApSAGg                           Wild Thaiger  3.034213
# e5kc0CQ4R-PCCDgb274gSg                            Canyon Cafe  2.736135
# gBcpDl0quCLABsg5OuSFww                  Teeter House Tea Room  1.242453
# 72N6TdH5MdUWE2YhYRbyxw                            Burger King -1.242453
# eOgUKCy5-sK-leqIBiNokg                     Copper Square Cafe  0.000000
# neGAQFkBNI8-rpPBLBzNkw                              Taco Bell  2.302585
# 45puCRQ6Vh_IIAy7kkfFDQ                 Majerle's Sports Grill  2.661505
# nc3IiY5LNdmEwUZCW84yuA                           Pizzeria Uno -1.445186
# P7wKlbSRsoRrfH3DFOY08A        International House of Pancakes  0.000000
# BESmH-lmMm34_EefL8X9fQ                    Comedor Guadalajara  5.579730
# D09yG6Z3gcsh24Qn7Y4gYA                          Chico's Tacos  0.000000
# kaIue7GRCmkPzDeHDBTttQ                       Phoenix Blue Fin  5.147494
# j8nyAaN_w5t6wYv-ni23sg                        Coach & Willies  0.000000
# 5XIvwfbIa-vuFEkkeCQ6kQ                       Jackson's On 3rd -2.197225
# VsO_rhXi5lgbaGxNwoEZsQ                               Fate 905  0.000000
# Y293fHh5SZ0_9BZm4M6BCg                     Matador Restaurant  0.000000
# IceZ4BtTz76eppjNWm-c6A                         Paisley Violin  2.038769
# QsvRjgQacMMFf8dit7qqDw                  New Garden Restaurant  2.890372
# LXhL5X3edNRy7epku6UAEw                        Paradise Bakery  1.945910
# -lOSaCuBRAvX5JBifx-EMw               Mi Amigo's Mexican Grill  0.000000
# XI-_Y2XRw03mozGx0Z90Gw               Baja Fresh Mexican Grill  1.522261
# qsWxbgQwuomXvMseg23DGg                                Hooters -2.363694
# DlCtdbceo4YNSI53cCL2lg              The Old Spaghetti Factory  0.000000
# kR5i58Pcse1FD9tk-yYLlA         Crave Sandwich Cafe & Catering  1.609438
# 2I666dqzs1XB6xigIKa9bA              Tom's Tavern & 1929 Grill  0.000000
# yExYqENb4F6qH6kJxTOaSQ            Karim's Cobbler Shop & Deli  1.472219
# 9BH18avE46LlHMvJn67MaA                      The Downtown Deli  4.043051
# ...                                                       ...       ...
# B4DU-hCTykF5_2q-9I4Chw               Char Pizzeria Napoletana  3.610918
# vT0hDJ9AL495p2tRYd922Q                     Buffalo Wild Wings  0.000000
# C_uN2pHwP4DlRwzAKVsabQ           The Speakeasy on Easy Street  1.609438
# AHcDWLn-OZR7qxoXwyfBoQ               Zu Izakaya Asian Kitchen  3.596843
# p9FwRY_KnxEHSI5op2qOvw                          Tortilla Fish  3.596843
# oMGhGXF_qCpM-eZSyfjOgw                 Phoenix Pizza Festival  0.549306
# OaJyFHQA-pAHsD_ev0fIWg                            Pita Jungle  2.302585
# py3nEoU90ZjVW7fPphNe8A                       Crazy Sushi Crab  5.129899
# d6xkQMRMFe-ZQAzBNkHuLw                              Fired Pie  0.972955
# CC8-73NAWvXKE1ArCkdMfg                        Dave & Buster's -3.332205
# NmDm0CFwN1YrqqqLZ4CCsg                             Loving Hut  4.158883
# TaKm7DeRsxz-xFVWX9XzPA                 Peoria Artisan Brewery  3.295837
# 97j8fecPqs_7-qbCjTlLEw                                   Salt  1.545521
# dMU3G63r4lo8iHIxGW5dXw                         Mike's Kitchen  3.453878
# cx6ht6xrOwHpNhXVQtgxiQ                 Salt Tacos and Tequila  0.000000
# d5UL7UjVnbJs8aiKzTCveg                  Mucha Lucha Taco Shop  2.197225
# qjRBMRCUlUx8Ofe9tiSlTA                       CoR Tapas & Wine  3.044522
# MOy6W061xpZq6co1nmEcfA                        The Local Press  4.969813
# zI9jtvCdSwIRwtY8qGdMpg                                Popeyes -3.596843
# I7uXE-VzXK3Cp4mvVp7osw                            Paz Cantina  1.386294
# i0qvOlxRMYTYm0ZG4BEulg                    American Way Market  4.158883
# MjnSTmlGlTt4LkKTao20FA                         Vinnie's Pizza  0.804719
# RbX5oXtNRuCqKiYchHRNFw                 Chipotle Mexican Grill  0.000000
# WCCRd8g_c6Hf93GAW4OjPQ             Kiss Pollos Estilo Sinaloa  3.218876
# FaymdoTfBSdPwg_ZfUE8zg                  Creek Side Taco Shack  3.727360
# dtlk15Awa7xWEVF9Z1Yqaw                           Panera Bread -0.895880
# T-LhjPRqlS7hLGRmSMBbfA                   Blue 32 Sports Grill  4.290459
# rtqtZ0_kOA-GP33mn6-Kpg                           Salad and Go  2.079442
# 7Hmr1TDJah-14zprHUMlqw  Singing Pandas Asian Restaurant & Bar  6.437752
# CVakWZjk_j44AB-Jbe0DPQ                        Rita's Burritos  4.493598
#
#                         alcohol  price_range  attire takeout waiter_service  \
# business_id
# x5Mv61CnZLohZWxfCVCPTQ        0          2.0  casual    True          False
# 2ZnCITVa0abGce4gZ6RhIw        0          1.0  casual    True            NaN
# EmzaQR5hQlF0WIl24NxAZA        2          1.0  casual   False          False
# KPoTixdjoJxSqRSEApSAGg        2          2.0  casual    True           True
# e5kc0CQ4R-PCCDgb274gSg        2          2.0  casual    True           True
# gBcpDl0quCLABsg5OuSFww        2          2.0  casual    True           True
# 72N6TdH5MdUWE2YhYRbyxw        0          3.0  casual    True          False
# eOgUKCy5-sK-leqIBiNokg        0          1.0  casual    True          False
# neGAQFkBNI8-rpPBLBzNkw        0          1.0  casual    True          False
# 45puCRQ6Vh_IIAy7kkfFDQ        2          2.0  casual    True           True
# nc3IiY5LNdmEwUZCW84yuA        2          2.0  casual    True           True
# P7wKlbSRsoRrfH3DFOY08A        0          1.0  casual    True           True
# BESmH-lmMm34_EefL8X9fQ        2          2.0  casual    True           True
# D09yG6Z3gcsh24Qn7Y4gYA        1          1.0  casual    True          False
# kaIue7GRCmkPzDeHDBTttQ        0          1.0  casual    True          False
# j8nyAaN_w5t6wYv-ni23sg        2          2.0  casual    True           True
# 5XIvwfbIa-vuFEkkeCQ6kQ        0          2.0  casual    True           True
# VsO_rhXi5lgbaGxNwoEZsQ        2          2.0  casual    True           True
# Y293fHh5SZ0_9BZm4M6BCg        2          2.0  casual    True           True
# IceZ4BtTz76eppjNWm-c6A        2          1.0  casual    True           True
# QsvRjgQacMMFf8dit7qqDw        0          2.0  casual    True           True
# LXhL5X3edNRy7epku6UAEw        0          NaN  casual     NaN            NaN
# -lOSaCuBRAvX5JBifx-EMw        2          2.0  casual    True           True
# XI-_Y2XRw03mozGx0Z90Gw        0          1.0  casual    True          False
# qsWxbgQwuomXvMseg23DGg        2          2.0  casual    True           True
# DlCtdbceo4YNSI53cCL2lg        2          2.0  casual    True           True
# kR5i58Pcse1FD9tk-yYLlA        0          1.0  casual    True          False
# 2I666dqzs1XB6xigIKa9bA        2          2.0  casual    True           True
# yExYqENb4F6qH6kJxTOaSQ        0          1.0  casual    True          False
# 9BH18avE46LlHMvJn67MaA        0          1.0  casual    True          False
# ...                         ...          ...     ...     ...            ...
# B4DU-hCTykF5_2q-9I4Chw        2          1.0  casual    True          False
# vT0hDJ9AL495p2tRYd922Q        2          2.0  casual    True          False
# C_uN2pHwP4DlRwzAKVsabQ        0          NaN  casual     NaN            NaN
# AHcDWLn-OZR7qxoXwyfBoQ        2          2.0  casual    True           True
# p9FwRY_KnxEHSI5op2qOvw        0          1.0  casual    True          False
# oMGhGXF_qCpM-eZSyfjOgw        1          1.0  casual     NaN            NaN
# OaJyFHQA-pAHsD_ev0fIWg        1          2.0  casual    True            NaN
# py3nEoU90ZjVW7fPphNe8A        0          2.0  casual    True           True
# d6xkQMRMFe-ZQAzBNkHuLw        0          2.0  casual    True            NaN
# CC8-73NAWvXKE1ArCkdMfg        2          2.0  casual    True           True
# NmDm0CFwN1YrqqqLZ4CCsg        0          1.0  casual    True          False
# TaKm7DeRsxz-xFVWX9XzPA        2          2.0  casual   False            NaN
# 97j8fecPqs_7-qbCjTlLEw        2          2.0  casual   False           True
# dMU3G63r4lo8iHIxGW5dXw        0          1.0  casual    True            NaN
# cx6ht6xrOwHpNhXVQtgxiQ        0          3.0  casual    True            NaN
# d5UL7UjVnbJs8aiKzTCveg        0          1.0  casual    True            NaN
# qjRBMRCUlUx8Ofe9tiSlTA        2          2.0  casual    True           True
# MOy6W061xpZq6co1nmEcfA        0          2.0  casual    True           True
# zI9jtvCdSwIRwtY8qGdMpg        0          2.0  casual    True            NaN
# I7uXE-VzXK3Cp4mvVp7osw        0          1.0  casual    True            NaN
# i0qvOlxRMYTYm0ZG4BEulg        0          1.0  casual    True            NaN
# MjnSTmlGlTt4LkKTao20FA        0          NaN  casual    True            NaN
# RbX5oXtNRuCqKiYchHRNFw        0          NaN  casual    True            NaN
# WCCRd8g_c6Hf93GAW4OjPQ        0          1.0  casual    True           True
# FaymdoTfBSdPwg_ZfUE8zg        0          2.0  casual    True            NaN
# dtlk15Awa7xWEVF9Z1Yqaw        0          1.0  casual     NaN            NaN
# T-LhjPRqlS7hLGRmSMBbfA        2          2.0  casual    True            NaN
# rtqtZ0_kOA-GP33mn6-Kpg        0          1.0  casual    True            NaN
# 7Hmr1TDJah-14zprHUMlqw        2          2.0  casual    True           True
# CVakWZjk_j44AB-Jbe0DPQ        0          1.0  casual    True          False
#
#                        outdoor_seating
# business_id
# x5Mv61CnZLohZWxfCVCPTQ           False
# 2ZnCITVa0abGce4gZ6RhIw             NaN
# EmzaQR5hQlF0WIl24NxAZA            True
# KPoTixdjoJxSqRSEApSAGg            True
# e5kc0CQ4R-PCCDgb274gSg            True
# gBcpDl0quCLABsg5OuSFww            True
# 72N6TdH5MdUWE2YhYRbyxw             NaN
# eOgUKCy5-sK-leqIBiNokg           False
# neGAQFkBNI8-rpPBLBzNkw           False
# 45puCRQ6Vh_IIAy7kkfFDQ            True
# nc3IiY5LNdmEwUZCW84yuA            True
# P7wKlbSRsoRrfH3DFOY08A           False
# BESmH-lmMm34_EefL8X9fQ           False
# D09yG6Z3gcsh24Qn7Y4gYA            True
# kaIue7GRCmkPzDeHDBTttQ            True
# j8nyAaN_w5t6wYv-ni23sg            True
# 5XIvwfbIa-vuFEkkeCQ6kQ            True
# VsO_rhXi5lgbaGxNwoEZsQ            True
# Y293fHh5SZ0_9BZm4M6BCg            True
# IceZ4BtTz76eppjNWm-c6A            True
# QsvRjgQacMMFf8dit7qqDw           False
# LXhL5X3edNRy7epku6UAEw             NaN
# -lOSaCuBRAvX5JBifx-EMw            True
# XI-_Y2XRw03mozGx0Z90Gw            True
# qsWxbgQwuomXvMseg23DGg            True
# DlCtdbceo4YNSI53cCL2lg           False
# kR5i58Pcse1FD9tk-yYLlA            True
# 2I666dqzs1XB6xigIKa9bA            True
# yExYqENb4F6qH6kJxTOaSQ           False
# 9BH18avE46LlHMvJn67MaA            True
# ...                                ...
# B4DU-hCTykF5_2q-9I4Chw           False
# vT0hDJ9AL495p2tRYd922Q            True
# C_uN2pHwP4DlRwzAKVsabQ            True
# AHcDWLn-OZR7qxoXwyfBoQ            True
# p9FwRY_KnxEHSI5op2qOvw            True
# oMGhGXF_qCpM-eZSyfjOgw             NaN
# OaJyFHQA-pAHsD_ev0fIWg             NaN
# py3nEoU90ZjVW7fPphNe8A            True
# d6xkQMRMFe-ZQAzBNkHuLw           False
# CC8-73NAWvXKE1ArCkdMfg            True
# NmDm0CFwN1YrqqqLZ4CCsg            True
# TaKm7DeRsxz-xFVWX9XzPA            True
# 97j8fecPqs_7-qbCjTlLEw            True
# dMU3G63r4lo8iHIxGW5dXw             NaN
# cx6ht6xrOwHpNhXVQtgxiQ             NaN
# d5UL7UjVnbJs8aiKzTCveg             NaN
# qjRBMRCUlUx8Ofe9tiSlTA           False
# MOy6W061xpZq6co1nmEcfA            True
# zI9jtvCdSwIRwtY8qGdMpg           False
# I7uXE-VzXK3Cp4mvVp7osw             NaN
# i0qvOlxRMYTYm0ZG4BEulg            True
# MjnSTmlGlTt4LkKTao20FA             NaN
# RbX5oXtNRuCqKiYchHRNFw             NaN
# WCCRd8g_c6Hf93GAW4OjPQ            True
# FaymdoTfBSdPwg_ZfUE8zg            True
# dtlk15Awa7xWEVF9Z1Yqaw             NaN
# T-LhjPRqlS7hLGRmSMBbfA            True
# rtqtZ0_kOA-GP33mn6-Kpg             NaN
# 7Hmr1TDJah-14zprHUMlqw           False
# CVakWZjk_j44AB-Jbe0DPQ            True
#
# [8917 rows x 11 columns]
