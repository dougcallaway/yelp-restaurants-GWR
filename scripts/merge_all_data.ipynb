# %%
# %matplotlib inline
from geopandas import GeoDataFrame, read_file
from geopandas.tools import sjoin
from shapely.geometry import Point
from pandas import to_numeric
from time import time

import jupynbimp
import restaurants_data_cleaning, census2010_data_cleaning, acs2013_data_cleaning

# %%
# Projected CRS: WGS 84/UTM Zone 12N
CRS = {'GCS':'+init=epsg:4326', 'projected':'+init=epsg:32612'}
USE_CACHE=True
SQ_METERS_PER_SQ_KM=1000000

# %%
def processingTime(start, finish):
    print('processing time: ' + str(round(finish - start, 2)) + 's')

def normalizeByArea(geoDataFrame, column):
    return geoDataFrame.apply(
        lambda row: row[column]/row.area_sqkm, axis=1
    )

# %% [markdown]
# ## Transform data into consolidated shapefile

# %% [markdown]
# ### Yelp Restaurants

# %%
restaurants = restaurants_data_cleaning.getData(fromCache=USE_CACHE)
restaurants = GeoDataFrame(
    restaurants,
    geometry=[Point(x,y) 
              for x, y in zip(restaurants.longitude,
                              restaurants.latitude)
             ],
    crs=CRS['GCS']
)
restaurants.to_crs(CRS['projected'], inplace=True)
restaurants.drop(['latitude', 'longitude'], axis=1, inplace=True)

# %% [markdown]
# ### Add Proximity Variables

# %%
# Retrieved 17/07/2016 from http://download.geofabrik.de/north-america/us/arizona.html
majorHighways = read_file('/arizona-latest/roads.shp', 
                          vfs='zip://../data/shapefiles/arizona-latest.zip'
                         )
majorHighways = (majorHighways[majorHighways['maxspeed'] >= 100]
                 .to_crs(CRS['projected'])
                )

start = time()
restaurants['dist_maj_hwy'] = restaurants.geometry.apply(
    lambda point: majorRoads.distance(point).min()
)
processingTime(start, time())
# Out:
# processing time: 357.65s

# %% [markdown]
# ### Census 2010

# %%
census2010 = census2010_data_cleaning.getData(fromCache=USE_CACHE)

# Retrieved 10-07-2016 from https://www.census.gov/cgi-bin/geo/shapefiles/index.php?year=2010&layergroup=Block+Groups
blockGroups2010 = read_file('/tl_2010_04_bg10.shp', 
                            vfs='zip://../data/shapefiles/tl_2010_04_bg10.zip')
blockGroups2010.GEOID10 = to_numeric(blockGroups2010.GEOID10)
blockGroups2010 = (blockGroups2010[['GEOID10','geometry']]
                   .rename(columns={'GEOID10':'GEOID'})
                   .to_crs(CRS['projected'])
                  )
blockGroups2010['area_sqkm'] = blockGroups2010.geometry.area/SQ_METERS_PER_SQ_KM 
blockGroups2010 = blockGroups2010.merge(census2010, on='GEOID')
   
# Normalize count data by block group area
blockGroups2010['population_density'] = normalizeByArea(blockGroups2010,'population_total')
blockGroups2010['home_mortgage_density'] = normalizeByArea(blockGroups2010,'home_mortgages')
blockGroups2010['home_owner_density'] = normalizeByArea(blockGroups2010,'home_owners')
blockGroups2010['renter_density'] = normalizeByArea(blockGroups2010,'renters')
blockGroups2010['household_density'] = normalizeByArea(blockGroups2010,'total_households')
blockGroups2010['family_household_density'] = normalizeByArea(blockGroups2010,'family_households')
blockGroups2010['single_household_density'] = normalizeByArea(blockGroups2010,'single_households')
blockGroups2010['hispanic_latino_population_density'] = normalizeByArea(blockGroups2010,'population_hispanic_latino')
blockGroups2010['white_population_density'] = normalizeByArea(blockGroups2010,'population_white')
blockGroups2010['black_population_density'] = normalizeByArea(blockGroups2010,'population_black')
blockGroups2010['native_american_population_density'] = normalizeByArea(blockGroups2010,'population_native_american')
blockGroups2010['asian_population_density'] = normalizeByArea(blockGroups2010,'population_asian')

blockGroups2010.drop(['population_total',
                      'home_mortgages',
                      'home_owners',
                      'renters',
                      'total_households',
                      'family_households',
                      'single_households','population_hispanic_latino',
                      'population_white',
                      'population_black',
                      'population_native_american',
                      'population_asian'
                     ], 
                     axis=1, inplace=True
                    )

# %% [markdown]
# ### ACS 2013

# %%
acs2013 = acs2013_data_cleaning.getData(fromCache=USE_CACHE) 

# Retrieved 10-07-2016 https://www.census.gov/cgi-bin/geo/shapefiles/index.php?year=2013&layergroup=Block+Groups
blockGroups2013 = read_file('/tl_2013_04_bg.shp', 
                            vfs='zip://../data/shapefiles/tl_2013_04_bg.zip')
blockGroups2013.GEOID = to_numeric(blockGroups2010.GEOID)
blockGroups2013 = (blockGroups2013[['GEOID','geometry']]
                   .to_crs(CRS['projected'])
                  )

blockGroups2013['area_sqkm'] = blockGroups2013.geometry.area/SQ_METERS_PER_SQ_KM 
blockGroups2013 = blockGroups2013.merge(acs2013, on='GEOID')
  
# Normalize count data by block group area
blockGroups2013['density_education_highschool'] = normalizeByArea(blockGroups2013,'education_highschool')
blockGroups2013['density_education_undergraduate'] = normalizeByArea(blockGroups2013,'education_undergraduate')
blockGroups2013['density_education_postgraduate'] = normalizeByArea(blockGroups2013,'education_postgraduate')

blockGroups2013.drop(['education_highschool',
                      'education_undergraduate',
                      'education_postgraduate'
                     ], 
                     axis=1, inplace=True
                    )

# %% [markdown]
# ## Spatial Join Restaurant Locations on Census Block Groups

# %%
start = time()
restaurants_census2010 = (sjoin(restaurants[['business_id', 'geometry']], blockGroups2010, how='inner')
                          .drop(['geometry', 'index_right', 'GEOID', 'area_sqkm'], axis=1)
                         )
restaurants_acs2013 = (sjoin(restaurants[['business_id', 'geometry']], blockGroups2013, how='inner')
                       .drop(['geometry', 'index_right', 'GEOID', 'area_sqkm'], axis=1)
                      )
restaurants_demographics = GeoDataFrame(restaurants_census2010.merge(restaurants_acs2013, on='business_id')
                                        .merge(restaurants, on='business_id'),
                                        crs=CRS['projected']
                                       )
processingTime(start, time())
# Out:
# processing time: 6.16s

# %%
restaurants_demographics
# Out:
#                  business_id  median_age  average_household_size  \
# 0     x5Mv61CnZLohZWxfCVCPTQ        45.8                    1.65
# 1     KPoTixdjoJxSqRSEApSAGg        45.8                    1.65
# 2     Vvh2Hd4SsZjEEfKLNKAEWw        45.8                    1.65
# 3     x8WoC_7WHzXNmt6J13Nbvw        45.8                    1.65
# 4     oSKT5oZX1NWYaHwOWL5lag        45.8                    1.65
# 5     QAe9UHKsxPdXQovBpaznMQ        45.8                    1.65
# 6     KIbFaBrZDX7rrYJInkv5Kg        45.8                    1.65
# 7     cN6aBxe2mQvrQlzk26LyRQ        45.8                    1.65
# 8     TCqkBVN84Ek0oLmZGAX5xA        45.8                    1.65
# 9     MJ6_uOT55dq5ALphFqMVkw        45.8                    1.65
# 10    IVc23uY-36WUNYoIbz42Fg        45.8                    1.65
# 11    E0fZHHInMb6xscHDrPlh4Q        45.8                    1.65
# 12    Z5v1F-tAV897ZmM32N0wfQ        45.8                    1.65
# 13    GDmue1oJaem9ilywDtA4_A        45.8                    1.65
# 14    e3v5KRh05Qqb64U6R8U-rA        45.8                    1.65
# 15    ZZC4cT0Jlfn8kmjgRPnwCA        45.8                    1.65
# 16    2ZnCITVa0abGce4gZ6RhIw        45.5                    1.98
# 17    bbi230ds25DLJ093eaSryQ        45.5                    1.98
# 18    vSWEXsXmJw5ozuF4zqE9ng        45.5                    1.98
# 19    LYcw5qaBPhfrXhdDLadU4A        45.5                    1.98
# 20    lK35BgpjOMXwchPzqYWomg        45.5                    1.98
# 21    i--afvRsP1TSJyQMZKgJiw        45.5                    1.98
# 22    EmzaQR5hQlF0WIl24NxAZA        22.4                    1.19
# 23    gBcpDl0quCLABsg5OuSFww        22.4                    1.19
# 24    eOgUKCy5-sK-leqIBiNokg        22.4                    1.19
# 25    45puCRQ6Vh_IIAy7kkfFDQ        22.4                    1.19
# 26    5XIvwfbIa-vuFEkkeCQ6kQ        22.4                    1.19
# 27    Y293fHh5SZ0_9BZm4M6BCg        22.4                    1.19
# 28    LXhL5X3edNRy7epku6UAEw        22.4                    1.19
# 29    XI-_Y2XRw03mozGx0Z90Gw        22.4                    1.19
# ...                      ...         ...                     ...
# 7798  rNl4WGa0FOm_neQKAlKSeQ        75.7                    1.62
# 7799  66uRGJVchKxS-8MdUWbc_g        64.3                    1.80
# 7800  gp_jHO6waljWuc0lRVtseQ        48.3                    2.24
# 7801  ZKHmSv7CqjlmeM7VSUnmcg        28.6                    3.92
# 7802  gi0rKzAS3aXD8No4SdXbGQ        30.6                    2.53
# 7803  DnnFh6Gn8dV6I20Hzy8a0g        26.2                    4.05
# 7804  XxZpdGVLCQs-sR1XZLbizQ        45.8                    2.41
# 7805  WlPYm5aK-ewwWeO4TlrF1g        38.6                    2.94
# 7806  N32F9DmtEp2AZQRyiAEiGg        33.4                    2.64
# 7807  wXRD9u4j_UCg_Xm4fSR78A        25.9                    1.94
# 7808  vFrtRRPFZs8qmJcMqbc81g        25.9                    1.94
# 7809  OSLBjNm6x_CvLO6rqj_SWQ        25.9                    1.94
# 7810  Nu42V8bUL3FYuNqVSNv0_g        25.9                    1.94
# 7811  DNHrQzg8WDrLjNEVa9PyGw        25.9                    1.94
# 7812  neQqbrgCqfrRjRaMY8iSGA        21.0                    3.95
# 7813  5yUFjReO99POREItTt5xww        34.9                    3.67
# 7814  MAA2X0e8t-J59AADJfL4cw        28.1                    3.76
# 7815  WtvgFwomRmd1tcGATO1jnQ        26.9                    1.84
# 7816  TW4rBIWv-oG32A4yCeJM8g        28.9                    3.43
# 7817  k5N9Wf6aijAll7XtGct_Dw        24.8                    4.06
# 7818  Dy6ll8Qc6_JBLfe3FhPqJg        29.4                    2.97
# 7819  FpIG-P9X9N1na7PXG6E7ig        33.6                    2.81
# 7820  uIlk2wYCZkdHI6N2nXcNQg        27.2                    3.31
# 7821  YyT1B4BRsr6bbX4abp4IbA        39.4                    3.19
# 7822  yt6qoOpq_aR9Lb9qogWW5w        46.4                    2.78
# 7823  qlPZ2nEcIrrA58tIXs3RKg        38.2                    2.49
# 8         526.190224         649.716587                200.529811
# 9         526.190224         649.716587                200.529811
# 10        526.190224         649.716587                200.529811
# 11        526.190224         649.716587                200.529811
# 12        526.190224         649.716587                200.529811
# 13        526.190224         649.716587                200.529811
# 14        526.190224         649.716587                200.529811
# 15        526.190224         649.716587                200.529811
# 16        369.929995         709.784380                339.854385
# 17        369.929995         709.784380                339.854385
# 18        369.929995         709.784380                339.854385
# 19        369.929995         709.784380                339.854385
# 20        369.929995         709.784380                339.854385
# 21        369.929995         709.784380                339.854385
# 22        456.934601         423.967843                 42.933452
# 23        456.934601         423.967843                 42.933452
# 24        456.934601         423.967843                 42.933452
# 25        456.934601         423.967843                 42.933452
# 26        456.934601         423.967843                 42.933452
# 27        456.934601         423.967843                 42.933452
# 28        456.934601         423.967843                 42.933452
# 29        456.934601         423.967843                 42.933452
# ...              ...                ...                       ...
# 7798       38.044763         664.664382                377.463723
# 7799       83.931737         338.159752                234.765583
# 7800      238.648533         783.603689                472.376478
# 7801     1091.310719         944.045778                761.127220
# 7802      797.036224        1060.363827                684.181538
# 7803     1328.977780         721.876567                555.754344
# 7804      200.660140         512.635394                344.198050
# 7805       40.614104          61.939054                 52.523503
# 7806      681.040537         859.716571                626.660874
# 7807      978.398321         567.322220                156.246120
# 7808      978.398321         567.322220                156.246120
# 7809      978.398321         567.322220                156.246120
# 7810      978.398321         567.322220                156.246120
# 7811      978.398321         567.322220                156.246120
# 7812     1943.603267        1593.513238               1327.927698
# 7813       79.494269         210.312509                192.561362
# 7814      963.547243         761.765434                610.038027
# 7815     2228.365193        1393.111390                412.262886
# 7816       41.459562          59.814361                 50.079867
# 7817     1135.673490         715.053679                625.321452
# 7818      435.947220         426.415578                297.989239
# 7819      511.726952         650.790635                476.789770
# 7820       36.779900          42.617980                 33.277053
# 7821      233.310965         579.473429                504.661761
# 7822       42.126631         184.360635                159.900010
# 7823        4.696630           8.498663                  5.623176
# 7824      522.504492         384.353378                309.489367
# 7825      296.756109         437.759509                287.906524
# 7826      750.469792         528.740081                393.509323
# 7827      543.155420         419.944361                373.740214
#
#       single_household_density      ...       \
# 0                   354.536706      ...
# 1                   354.536706      ...
# 2                   354.536706      ...
# 3                   354.536706      ...
# 4                   354.536706      ...
# 5                   354.536706      ...
# 6                   354.536706      ...
# 7                   354.536706      ...
# 8                   354.536706      ...
# 9                   354.536706      ...
# 10                  354.536706      ...
# 11                  354.536706      ...
# 12                  354.536706      ...
# 13                  354.536706      ...
# 14                  354.536706      ...
# 15                  354.536706      ...
# 16                  252.635118      ...
# 17                  252.635118      ...
# 18                  252.635118      ...
# 19                  252.635118      ...
# 20                  252.635118      ...
# 21                  252.635118      ...
# 22                  350.367639      ...
# 23                  350.367639      ...
# 24                  350.367639      ...
# 25                  350.367639      ...
# 26                  350.367639      ...
# 27                  350.367639      ...
# 28                  350.367639      ...
# 29                  350.367639      ...
# ...                        ...      ...
# 7798                264.821387      ...
# 7799                 92.446551      ...
# 7800                234.958092      ...
# 7801                130.213211      ...
# 7802                253.923045      ...
# 7803                102.693738      ...
# 7804                133.285202      ...
# 7805                  6.972597      ...
# 7821                                   Angry Crab Shack  5.709994        2
# 7822               My Sweet Blessings Bakery and Bistro  2.772589        1
# 7823                                      Florence Cafe  0.000000        0
# 7824                           Filiberto's Mexican Food  1.386294        0
# 7825                                      Momenti Pizza  0.000000        0
# 7826                                         Suki's BBQ  2.079442        0
# 7827                                    Jack In The Box  1.386294        0
#
#       price_range  attire takeout waiter_service  outdoor_seating  \
# 0               2  casual    True          False            False
# 1               2  casual    True           True             True
# 2              NA  casual    True          False            False
# 3               1  casual      NA          False               NA
# 4               2  casual    True           True            False
# 5               1  casual    True          False            False
# 6               1  casual    True          False            False
# 7               3  dressy   False           True            False
# 8               2  casual    True           True             True
# 9               1  casual    True          False             True
# 10              2  casual    True           True             True
# 11              2  casual    True           True            False
# 12              1  casual    True           True            False
# 13              2  casual    True           True            False
# 14              1  casual    True          False             True
# 15              2  casual    True           True             True
# 16              1  casual    True             NA               NA
# 17              1  casual    True             NA               NA
# 18              2  casual    True           True            False
# 19              2  casual    True           True             True
# 20              1  casual    True          False             True
# 21              1  casual    True          False             True
# 22              1  casual   False          False             True
# 23              2  casual    True           True             True
# 24              1  casual    True          False            False
# 25              2  casual    True           True             True
# 26              2  casual    True           True             True
# 27              2  casual    True           True             True
# 28             NA  casual      NA             NA               NA
# 29              1  casual    True          False             True
# ...           ...     ...     ...            ...              ...
# 7798           NA  casual    True             NA               NA
# 7799            1  casual    True             NA            False
# 7800            2  casual    True             NA            False
# 7801            2  casual    True             NA            False
# 7802            1  casual    True          False            False
# 7803            1  casual      NA           True             True
# 7804            1  casual    True          False            False
# 7805            2  casual    True           True             True
# 7806            2  casual    True          False             True
# 7807            2  casual    True           True             True
# 7808            2  casual    True           True             True
# 7809            2  casual    True             NA            False
# 7810            2  casual    True           True             True
# 7811            1  casual    True             NA             True
# 7812            1  casual    True          False             True
# 7813            2  casual    True           True             True
# 7814            1  casual    True          False             True
# 7815            1  casual    True          False             True
# 7816            2  casual    True             NA               NA
# 7817           NA  casual      NA             NA               NA
# 7818           NA  casual    True             NA               NA
# 7819            1  casual    True          False             True
# 7820            1  casual    True          False            False
# 7821            2  casual    True           True            False
# 7822            1  casual    True          False             True
# 7823            1  casual    True           True               NA
# 7824            1  casual    True             NA            False
# 7825            1  casual    True             NA            False
# 7826           NA  casual      NA             NA               NA
# 7827           NA  casual      NA             NA               NA
#
#                                          geometry  dist_maj_hwy
# 0     POINT (400244.9491822217 3704960.015533127)   1906.964491
# 1     POINT (400267.6733166573 3704788.713454979)   1734.326517
# 2     POINT (400280.6015136967 3704952.583430165)   1896.420387
# 3      POINT (400314.014571388 3704749.978199139)   1691.659300
# 4     POINT (400244.9150034722 3704959.406001454)   1906.360341
# 5     POINT (400240.1912067185 3704645.397384088)   1593.988804
# 6     POINT (400672.1663762873 3704972.762577508)   1886.779947
# 7      POINT (400268.7285709459 3704709.19574977)   1655.025026
# 8     POINT (401036.0086786781 3704411.102884501)   1346.948867
# 9     POINT (400282.9138216604 3704992.900651154)   1936.377137
# 10     POINT (400248.1424391833 3704688.22889756)   1635.953293
# 11    POINT (401036.5101676268 3704370.291036807)   1306.419052
