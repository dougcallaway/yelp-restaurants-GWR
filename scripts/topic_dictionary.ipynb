# %%
topicDictionary = {'service': 
                   ['service', 'seat', 'slow', 'fast', 'forever', 'finally', 'minutes', 
                    'minute', 'took', 'wait', 'away', 'staff', 'order', 'ordered', 'want', 
                    'wanted', 'friendly', 'helpful', 'help', 'attentive', 'care', 'chef', 
                    'waiter', 'waitress', 'bartender', 'complaint', 'cook', 'customer', 
                    'customers', 'delivery', 'employees', 'greeted', 'immediately', 'job',
                    'kind', 'manager', 'offer', 'offered', 'option', 'options', 'ordering',
                    'orders', 'owned', 'owner', 'owners', 'quick', 'quickly', 'seated', 'serve',
                    'served', 'server', 'servers', 'table', 'tables', 'apologized', 'apology', 
                    'attention', 'attitude', 'available', 'company', 'complain', 'complaint',
                    'deliver', 'delivered', 'dropped', 'employee', 'fault', 'fix', 'hostess', 
                    'management', 'mistake', 'online', 'patrons', 'phone', 'problem', 'requested',
                    'reservation', 'response', 'serving', 'sorry', 'treated', 'waitresses'
                   ],
                   
                   'food': 
                   ['vegetables', 'menu', 'fruit', 'meat', 'rich', 'mexican', 'chips', 'fresh', 
                    'salsa', 'carne', 'sweet', 'potato', 'mac', 'cheese', 'lobster', 'food', 
                    'chicken', 'taste', 'tasted', 'delicious', 'ice', 'cream', 'moist', 'dry', 
                    'rare', 'chili', 'chile', 'slice', 'slices', 'cup', 'chipotle', 'appetizer',
                    'appetizers', 'asada', 'asian', 'ate', 'eat', 'eaten', 'avocado', 'water',
                    'wings', 'yum', 'yummy', 'bacon', 'bbq', 'bean', 'beans', 'beef', 'bite', 
                    'bread', 'brisket', 'buffet', 'burger', 'burgers', 'burrito', 'butter', 'chef',
                    'chinese', 'chocolate', 'coffee', 'combination', 'combo', 'cook', 'homemade', 
                    'cooked', 'corn', 'course', 'crab', 'craving', 'creamy', 'crisp', 'crispy', 
                    'crust', 'curry', 'cut', 'delish', 'dessert', 'desserts', 'dining', 'dish',
                    'dishes', 'door', 'downtown', 'drink', 'eat', 'eaten', 'eating', 'egg', 'eggs',
                    'entree', 'entrees', 'filled', 'filling', 'fish', 'flavor', 'flavorful', 
                    'flavors', 'french', 'fried', 'fries', 'garlic', 'glass', 'greasy', 'greek',
                    'green', 'grill', 'guacamole', 'healthy', 'hummus', 'hungry', 'iced',
                    'ingredients', 'italian', 'juicy', 'lamb', 'lemon', 'lettuce', 'main', 'meal',
                    'meals', 'meats', 'medium', 'mouth', 'mushrooms', 'noodles', 'onion', 'onions',
                    'orange', 'pancakes', 'pasta', 'pepper', 'peppers', 'pho', 'pie', 'pita', 
                    'pizza', 'pizzas', 'plate', 'plates', 'pork', 'portion', 'portions', 'potatoes',
                    'prepared', 'rib', 'ribs', 'rice', 'rich', 'roasted', 'roll', 'rolls', 'salad',
                    'salads', 'salmon', 'sandwich', 'sandwiches', 'sauce', 'sauces', 'sausage',
                    'seafood', 'seasoned', 'shrimp', 'sides', 'soup', 'sour', 'spice', 'spicy',
                    'spinach', 'steak', 'stuffed', 'sushi', 'taco', 'tacos', 'tastes', 'tasting',
                    'tasty', 'tea', 'tender', 'thai', 'toast', 'tomato', 'tomatoes', 'toppings', 
                    'tuna', 'turkey', 'veggie', 'veggies', 'baked', 'bites', 'bland', 'bottle', 'bowl',
                    'bun', 'burnt', 'chewy', 'cooking', 'edible', 'flavorless', 'frozen', 'grease',
                    'grilled', 'inedible', 'menus', 'oil', 'overcooked', 'piece', 'pieces', 'raw',
                    'refill', 'refills', 'salt', 'salty', 'seasoning', 'selection', 'soda', 'soggy',
                    'stale', 'stomach', 'tasteless', 'texture', 'tortilla', 'tough', 'undercooked'
                   ],
                       
                   'atmosphere': 
                   ['atmosphere', 'ambiance', 'experience', 'hidden', 'place', 'vibe', 'look', 'looked', 
                    'feel', 'feels', 'felt', 'smell', 'smelled', 'smells', 'talk', 'talking', 'area', 
                    'outdoor', 'outside', 'authentic', 'business', 'busy', 'cafe', 'cake', 'casual', 
                    'chain', 'clean', 'comfort', 'comfortable', 'corner', 'counter', 'cozy', 'crowded',
                    'cute', 'dark', 'decor', 'desert', 'dog', 'east', 'environment', 'establishment', 
                    'fancy', 'feeling', 'fun', 'game', 'heat', 'inside', 'joint', 'kitchen', 'light', 
                    'local', 'packed', 'patio', 'loud', 'mall', 'middle', 'modern', 'music', 'party', 
                    'people','person', 'room', 'seating', 'shop', 'space', 'sports', 'store', 'street',
                    'table', 'tables', 'wall', 'warm', 'bag', 'bathroom', 'bell', 'birthday', 'booth', 
                    'boring', 'bother', 'conversation', 'crowd', 'floor', 'mess','paper', 'plastic', 
                    'ranch', 'window'
                   ],
                      
                   'location': 
                   ['local', 'located', 'location', 'near', 'neighborhood', 'walking', 'walk', 'drove', 
                    'drive', 'park', 'parking', 'arizona', 'az', 'area', 'phoenix', 'scottsdale', 'spot', 
                    'street', 'tempe', 'town', 'trip', 'valley', 'visit', 'visiting', 'visited', 'car', 
                    'home', 'house', 'locations', 'st', 'walked'
                   ],
                   
                   'people': 
                   ['boyfriend', 'girlfriend', 'wife', 'husband', 'friend', 'friends', 'partner',
                    'partners', 'group', 'date', 'family', 'kids', 'mom', 'dad', 'share', 'shared','daughter', 
                    'daughters', 'son', 'sons', 'guests', 'kid'
                   ],
                      
                   'time': 
                   ['time', 'times', 'morning', 'mornings', 'afternoon', 'afternoons', 'evening', 'evenings', 
                    'sunday', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sundays', 
                    'mondays', 'tuesdays', 'wednesdays', 'thursdays', 'fridays', 'saturdays', 'breakfast', 
                    'lunch', 'dinner', 'breakfasts', 'lunches', 'dinners', 'happy hour', 'happy hours', 
                    'night', 'nights', 'day', 'days', 'close', 'closed', 'closing', 'open', 'opened', 'opening', 
                    'ago', 'week', 'weekday', 'weekdays', 'weekend', 'weekends', 'month', 'months', 'year',
                    'years', 'brunch', 'early', 'late', 'later', 'am', 'pm', 'regular', 'today', 'tonight', 
                    'end', 'ended', 'start', 'started', 'long', 'longer', 'past', 'previous', 'recently', 'first', 
                    'second', 'third', 'start', 'started', 'finish', 'weeks', 'yesterday', 'soon'
                   ],
                      
                   'alcohol': 
                   ['happy hour', 'happy hours', 'alcohol', 'drink', 'drinks', 'beer', 'beers', 'wine', 'bar', 
                    'bartender', 'cocktails', 'margarita', 'margaritas'
                   ],
                      
                   'opinion': 
                   ['worse', 'worst', 'terrible', 'horrible', 'just', 'needs', 'ok', 'prefer', 'bad', 'poor', 
                    'poorly', 'par', 'nice', 'nice', 'nicely', 'pleasant', 'pleasantly', 'good', 'quality', 
                    'excellent', 'super', 'awesome', 'fantastic', 'amazing', 'better', 'best', 'great', 
                    'greatest', 'love', 'definitely', 'recommend', 'phenomenal', 'really', 'alot', 'needless', 
                    'sure', 'think', 'know', 'lol', 'non', 'refreshing', 'absolutely', 'average', 'wish', 
                    'wonderful', 'beautiful', 'believe', 'big', 'certainly', 'crazy', 'decent', 'disappointed', 
                    'easily', 'easy', 'enjoy', 'enjoyed', 'exactly', 'excited', 'extremely', 'fabulous', 'fair', 
                    'fantastic', 'far', 'favorite', 'favorites', 'fine', 'generous', 'glad', 'hard', 'huge',
                    'impressed', 'incredible', 'interesting', 'kind','slow', 'fast', 'friendly', 'helpful', 
                    'attentive', 'care', 'like', 'liked', 'little', 'long', 'loved', 'lovely', 'loves', 'low', 
                    'high', 'maybe', 'miss', 'mixed', 'new', 'okay', 'old', 'outstanding', 'perfect', 'perfection',
                    'perfectly', 'pleased', 'plenty', 'quick', 'quickly', 'reasonable', 'reasonably', 
                    'recommended', 'satisfied', 'short', 'simple', 'simply', 'slightly', 'small', 'soft', 'solid', 
                    'surprised', 'totally', 'traditional', 'treat', 'true', 'truly', 'typical', 'unique', 
                    'variety', 'wow', 'alright', 'avoid', 'awful', 'barely', 'basic', 'basically', 'choice', 
                    'choices', 'chose', 'completely', 'considering', 'correct', 'crap', 'decide', 'decided', 
                    'despite', 'different', 'disappointing', 'disappointment', 'disgusting', 'doubt', 'expect', 
                    'expectations', 'expected', 'expecting', 'fairly', 'figured', 'gross', 'guess', 'hardly', 
                    'hate', 'hell', 'highly', 'hope', 'hopes', 'hoping', 'ignored', 'imagine', 'incredibly', 
                    'informed', 'issue', 'issues', 'kinda', 'lack', 'lacked', 'lacking', 'likely', 'limited', 
                    'lots', 'lot', 'luck', 'mediocre', 'meh', 'nasty', 'need', 'needed', 'negative', 'normal', 
                    'normally', 'obviously', 'odd', 'opinion', 'overall', 'overly', 'pick', 'picked', 'poorly', 
                    'positive', 'possible', 'pretty', 'probably', 'quite', 'rating', 'real', 'reason', 'review', 
                    'reviews', 'rediculous', 'right', 'rude', 'rush', 'sad', 'sadly', 'sense', 'seriously', 
                    'shame', "shouldn't", 'sick', 'similar', 'star', 'stars', 'strange', 'sucks', 'supposed', 
                    'thinking', 'thought', 'tiny', 'understand', 'unfortunately', 'upset', 'weird', 'wonder', 
                    'wrong', 'young'
                   ],
                      
                   'cost': 
                   ['cost', 'bill', 'check', 'cheap', 'expensive', 'deal', 'extra', 'free', 'happy hour', 
                    'money', 'pay', 'paid', 'price', 'prices', 'priced', 'pricey', 'special', 'specials', 'tip', 
                    'value', 'worth', 'bought', 'bucks', 'buy', 'card', 'cash', 'cashier', 'charge', 'charged', 
                    'coupon', 'credit', 'dollar', 'dollars', 'overpriced', 'paying', 'save', 'total'
                   ]
                  }
